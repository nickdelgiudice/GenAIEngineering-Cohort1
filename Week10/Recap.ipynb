# %% [markdown]
# ### 🧠 1. Pandas DataFrames

# %% [markdown]
# ### ✂️ 2. Core NLP: Tokenization, POS, Word2Vec

# %% [markdown]
# ### 🤖 3. Classical ML: Classification

# %% [markdown]
# ### 🔮 4. LLMs, ChatBots, RAGBots, Agents

# %% [markdown]
# ### 🧠 5. Embeddings, Chunking, Vector Stores, Semantic Search

# %% [markdown]
# ### 📊 6. Tabular RAG & Conversational Bots
