# %%
import pandas as pd
import csv
from dotenv import load_dotenv
from groq import Groq

# %% [markdown]
# **Pandas**
# When there is a CSV data, efficient and effective way to handle is to use pandas
# This can be used for various data handlind and manipulation
# That makes a good choice for Data Retirieval mechanism

# %%
Data = pd.read_csv ('Student_Performance.csv')
print (Data.dtypes)
# Out:
# student_id                        object
# age                                int64
# gender                            object
# study_hours_per_day              float64
# social_media_hours               float64
# netflix_hours                    float64
# part_time_job                     object
# attendance_percentage            float64
# sleep_hours                      float64
# diet_quality                      object
# exercise_frequency                 int64
# parental_education_level          object
# internet_quality                  object
# mental_health_rating               int64
# extracurricular_participation     object
# exam_score                       float64
# dtype: object

# %% [markdown]
# >Check pandas functions that can be used for data calculations and inference

# %%
# various data computation possible
print ('Number of records : ', len (Data))
print ('Min, Avg, Max Study Hours : ', Data['study_hours_per_day'].min(), Data['study_hours_per_day'].mean(), Data['study_hours_per_day'].max())
print ("Values in Paretal Education :", Data['parental_education_level'].unique())
print ("Values in Internet Quality :", Data['internet_quality'].unique())
# Out:
# Number of records :  1000
# Min, Avg, Max Study Hours :  0.0 3.5501000000000005 8.3
# Values in Paretal Education : ['Master' 'High School' 'Bachelor' nan]
# Values in Internet Quality : ['Average' 'Poor' 'Good']

# %% [markdown]
# **Filtering**
# Pandas provides conditional filter / slicing functions that can be used as part of retrieval
# Result again in another pandas dataframe

# %%
# filter for poor internet quality and score more than 90
# All columns considered
Filtered = Data[(Data['internet_quality'] =='Poor') & (Data['exam_score'] > 90.0)]
Filtered
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 184      S1184   17  Female                  4.9                 0.0
# 230      S1230   22    Male                  4.2                 0.3
# 315      S1315   24  Female                  4.5                 3.4
# 320      S1320   24  Female                  4.6                 1.8
# 336      S1336   21  Female                  6.6                 2.2
# 567      S1567   24    Male                  4.7                 4.1
# 597      S1597   23    Male                  4.9                 1.6
# 606      S1606   23    Male                  6.8                 2.5
# 611      S1611   18    Male                  6.0                 1.6
# 688      S1688   23    Male                  5.0                 1.8
# 750      S1750   24  Female                  6.1                 1.9
# 764      S1764   21    Male                  6.6                 2.6
# 861      S1861   17    Male                  3.9                 1.9
# 862      S1862   18  Female                  5.5                 2.0
# 885      S1885   21    Male                  5.2                 0.0
# 951      S1951   20  Female                  3.3                 2.2
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 184            0.7            No                   71.2          6.4
# 230            0.1            No                   80.0          7.9
# 315            0.4            No                   79.6          6.1
# 320            1.5            No                   80.9          8.2
# 336            2.7            No                   73.0          6.4
# 567            3.0            No                   71.2          4.9
# 597            4.0            No                   87.1          8.0
# 606            0.7            No                   97.2          4.4
# 611            1.3            No                   89.7          5.5
# 688            1.6            No                  100.0          5.7
# 750            0.2            No                   97.6          5.9
# 764            1.5            No                   84.7          7.9
# 861            0.2            No                   82.4          8.4
# 862            0.0            No                   90.1          6.2
# 885            1.3            No                   87.7          8.7
# 951            0.9            No                   76.7          8.7
#
#     diet_quality  exercise_frequency parental_education_level  \
# 184         Fair                   5                   Master
# 230         Poor                   3              High School
# 315         Fair                   5              High School
# 320         Fair                   5                      NaN
# 336         Good                   2                 Bachelor
# 567         Good                   3                 Bachelor
# 597         Fair                   5                 Bachelor
# 606         Good                   1                 Bachelor
# 611         Fair                   6              High School
# 688         Good                   6              High School
# 750         Poor                   6                 Bachelor
# 764         Fair                   1                   Master
# 861         Fair                   4                 Bachelor
# 862         Good                   5              High School
# 885         Fair                   6              High School
# 951         Good                   5                 Bachelor
#
#     internet_quality  mental_health_rating extracurricular_participation  \
# 184             Poor                     5                            No
# 230             Poor                     9                           Yes
# 315             Poor                    10                            No
# 320             Poor                     9                           Yes
# 336             Poor                     8                           Yes
# 567             Poor                    10                           Yes
# 597             Poor                     7                            No
# 606             Poor                     4                            No
# 611             Poor                     7                            No
# 688             Poor                     7                            No
# 750             Poor                     6                            No
# 764             Poor                     2                            No
# 861             Poor                     9                           Yes
# 862             Poor                     1                            No
# 885             Poor                     8                            No
# 951             Poor                    10                            No
#
#      exam_score
# 184        96.2
# 230       100.0
# 315        98.8
# 320        94.2
# 336       100.0
# 567        93.1
# 597        95.5
# 606        93.1
# 611       100.0
# 688        92.9
# 750        98.5
# 764        96.6
# 861        93.5
# 862        93.7
# 885       100.0
# 951        94.0

# %%
# Filter for above average study hours and attendance, but low marks
Filtered = Data[(Data['study_hours_per_day'] >= Data['study_hours_per_day'].mean()) & 
                (Data['attendance_percentage'] >= Data['attendance_percentage'].mean()) & 
                (Data['exam_score'] < 60)]
Filtered
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 179      S1179   19  Female                  3.8                 1.7
# 491      S1491   21  Female                  4.0                 4.3
# 730      S1730   19  Female                  4.3                 2.7
# 763      S1763   18    Male                  3.9                 2.4
# 782      S1782   24  Female                  3.9                 3.3
# 804      S1804   22  Female                  4.3                 4.0
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 179            3.8            No                   90.2          5.3
# 491            2.4            No                   84.8          8.3
# 730            2.6           Yes                   91.9          5.0
# 763            0.0           Yes                   91.1          5.5
# 782            1.1           Yes                   90.6          8.6
# 804            1.1           Yes                   88.4          4.4
#
#     diet_quality  exercise_frequency parental_education_level  \
# 179         Good                   2              High School
# 491         Good                   0              High School
# 730         Good                   3                 Bachelor
# 763         Good                   3              High School
# 782         Fair                   0                      NaN
# 804         Good                   2              High School
#
#     internet_quality  mental_health_rating extracurricular_participation  \
# 179          Average                     4                            No
# 491             Good                     2                            No
# 730             Good                     1                            No
# 763             Poor                     1                           Yes
# 782             Good                     3                            No
# 804          Average                     2                           Yes
#
#      exam_score
# 179        58.1
# 491        53.0
# 730        58.4
# 763        59.5
# 782        56.0
# 804        59.0

# %% [markdown]
# **Use as Context**
# The data filtered using pandas used as context to provide LLM the data
# This data retrieval can be quick and effective

# %%
load_dotenv()
client = Groq()

# %% [markdown]
# >Specific instructions in terms of Response

# %%
R_Instr = "Using the context given, provide response to the user question or statement.\
            Context is provided as CSV formatted string.\
            Answer to the question with details"

# %%
# User prompt
Prompt = "Why do you think students score low marks despite attending class and studying well?"

Filtered = Data[(Data['study_hours_per_day'] >= Data['study_hours_per_day'].mean()) & 
                (Data['attendance_percentage'] >= Data['attendance_percentage'].mean()) & 
                (Data['exam_score'] < 60)]
Context = Filtered.to_csv (index=False, float_format='%.1f')

# Invoke LLM with prompt and context
messages=[
    {
        "role": "system",
        "content": R_Instr
    },

    {
        "role": "user",
        "content":"Context : \n"+ Context + "Query : \n" + Prompt
    }
]
completion = client.chat.completions.create(
    messages=messages,
    model="llama3-70b-8192",
)

print (completion.choices[0].message.content)
# Out:
# Based on the data provided, there are several possible reasons why students might score low marks despite attending class and studying well:
#
# 1. **Limited study hours**: Although students attend classes regularly, their study hours per day might not be sufficient to grasp and retain the material. For instance, students S1179 and S1491 study for 3.8 and 4.0 hours per day, respectively, which might not be enough to cover the vast syllabus.
#
# 2. **Distractions from social media and Netflix**: Social media and Netflix can be significant distractions, and the time spent on these activities might negatively impact academic performance. Students S1179, S1491, and S1782 spend 1.7, 4.3, and 3.3 hours per day, respectively, which could be affecting their studies.
#
# 3. **Diet quality and exercise frequency might also play a role**: A healthy diet and regular exercise can significantly impact mental health and cognitive function. Students S1179, S1491, and S1730 have a good diet quality, but their exercise frequency is relatively low (2, 0, and 3 times per week, respectively).
#
# 4. **Part-time job and mental health**: Having a part-time job might add to the mental health burden, leading to decreased academic performance. For example, students S1730, S1782, and S1804 have part-time jobs, which could be affecting their mental health rating (1, 3, and 2, respectively).
#
# 5. **Parental education level**: The education level of parents might influence the academic performance of children. Students S1179, S1491, S1730, and S1804 have parents with a high school or bachelor's degree, which might not provide the necessary academic support.
#
# 6. **Internet quality**: Poor internet quality can hinder access to online resources, affecting academic performance. Student S1763 has poor internet quality, which might be impacting their studies.
#
# 7. **Mental health rating**: A low mental health rating can significantly impact academic performance. Students S1179, S1491, and S1782 have a mental health rating of 4, 2, and 3, respectively, which might be affecting their exam scores.
#
# 8. **Lack of extracurricular participation**: Not participating in extracurricular activities might limit opportunities for learning outside the classroom. Students S1179, S1491, S1730, and S1782 do not participate in extracurricular activities, which could be affecting their overall academic performance.
#
# These are just a few possible reasons** why students might score low despite attending class and studying well. A more in-depth analysis would require additional data and a more comprehensive understanding of each student's individual circumstances.

# %% [markdown]
# >Let's try adapting the response

# %%
R_Instr = "Using the context given, provide response to the user question or statement.\
            Context is provided as CSV formatted string.\
            Provide comprehensive response"

# %%
# User prompt
Prompt = "Students who have good sleep patterns, are they utlising the time properly?"

# Filter relevant rows for above average sleep time and >75 mark. Only relevant columns
Filtered = Data.loc[(Data['sleep_hours'] >= Data['sleep_hours'].mean()*1.1) & 
                (Data['exam_score'] >= 75),
                ['study_hours_per_day', 'social_media_hours', 'netflix_hours', 'part_time_job', 'attendance_percentage']]
Context = Filtered.to_csv (index=False, float_format='%.1f')

# Invoke LLM with prompt and context
messages=[
    {
        "role": "system",
        "content": R_Instr
    },

    {
        "role": "user",
        "content":"Context : \n"+ Context + "Query : \n" + Prompt
    }
]
completion = client.chat.completions.create(
    messages=messages,
    model="llama3-70b-8192",
)

print (completion.choices[0].message.content)
# Out:
# To determine if students with good sleep patterns are utilizing their time properly, we'll analyze the correlation between the "study-hours-per-day" and the "attendance-percentage".
#
# Let's define "good sleep pattern" as having at least 7 hours of sleep per day (study_hours_per_day ≥ 7).
#
# After filtering the data, we get 13 students with good sleep patterns, and their corresponding study hours, social media hours, Netflix hours, part-time job, and attendance percentages are:
#
# study_hours_per_day,social_media_hours,netflix_hours,part_time_job,attendance_percentage
# 7.2,3.7,0.0,No,100.0
# 7.2,3.7,0.0,No,100.0
# 7.3,1.7,1.6,No,79.5
# 7.5,3.6,1.9,Yes,85.9
# 6.8,3.7,1.8,No,72.3
# 6.6,2.8,2.1,No,84.3
# 6.5,3.5,3.9,No,100.0
# 6.3,1.5,0.0,No,83.3
# 6.6,3.2,2.6,No,86.5
# 6.2,3.5,2.3,No,94.5
# 6.7,1.4,0.9,No,100.0
# 6.3,3.0,1.6,No,93.6
# 6.0,2.2,2.8,Yes,83.1
#
# Now, let's calculate the mean of the attendance percentages for these students:
#
# The mean attendance percentage for students with good sleep patterns is approximately 86.5%. This is higher than the overall mean attendance percentage (around 84.5%).
#
# This suggests that students with good sleep patterns tend to have better attendance records, indicating that they are utilizing their time more effectively.
#
# However, it's essential to note that having good sleep patterns doesn't necessarily mean a student is utilizing their time properly. There might be other factors influencing their attendance and time management.

# %% [markdown]
# **Get Code from LLM**
# Like in SQL, in pandas also we can take help of LLM to generate code
# This would require specific instructions to be provided for code generation
# The generated code can be used to extract data from dataframe and then use it as context

# %%
C_Instr = "For the given pandas dtypes, write code lines that can filter out data to answer user question.\
            Study the pandas dtypes and user question clearly\
            Give only the python code lines for necessary filtering of the Dataframe variable.\
            Code that can filter and return dataframe. Assign results to 'Result'\
            No additional code / string"

# %%
# Invoke LLM with prompt and context
Prompt = "Who all have good score despite having attendance below 75?"
# Prompt = "how many scored > 90% with less than 70% attendance?"
# Prompt = "What are the students who score good despite of low study time do?"

Data_Frame_Name = "Data"

Dtype = str(Data.dtypes)

messages=[
    {
        "role": "system",
        "content": C_Instr
    },

    {
        "role": "user",
        "content": "Data.dtype : \n"+ Dtype + "Dataframe variable : 'Data'\n Question : \n" + Prompt
    }
]
completion = client.chat.completions.create(
    messages=messages,
    model="llama3-70b-8192",
)

Code = completion.choices[0].message.content
Code_Clean = Code.strip ("`")
print (Code_Clean)

exec (Code_Clean)
# print (Result)

Context = Result.to_csv (index=False, float_format='%.1f')

# Invoke LLM with prompt and context
messages=[
    {
        "role": "system",
        "content": R_Instr
    },

    {
        "role": "user",
        "content":"Context : \n"+ Context + "Query : \n" + Prompt
    }
]
completion = client.chat.completions.create(
    messages=messages,
    model="llama3-70b-8192",
)

print (completion.choices[0].message.content)
# Out:
# Result = Data[(Data['attendance_percentage'] < 75) & (Data['exam_score'] > 50)]
# Based on the provided data, the students who have a good score (above 75) despite having attendance below 75 are:
#
# 1. S1043 - Attendance: 62.8, Exam Score: 65.7
# 2. S1069 - Attendance: 72.3, Exam Score: 100.0
# 3. S1080 - Attendance: 64.0, Exam Score: 70.7
# 4. S1110 - Attendance: 64.3, Exam Score: 86.5
# 5. S1134 - Attendance: 73.2, Exam Score: 70.7
# 6. S1147 - Attendance: 64.3, Exam Score: 78.1
# 7. S1161 - Attendance: 73.8, Exam Score: 76.8
# 8. S1177 - Attendance: 71.0, Exam Score: 68.3
# 9. S1225 - Attendance: 64.3, Exam Score: 74.3
# 10. S1240 - Attendance: 72.0, Exam Score: 51.2
# 11. S1272 - Attendance: 74.7, Exam Score: 76.2
# 12. S1289 - Attendance: 74.3, Exam Score: 73.5
# 13. S1308 - Attendance: 69.4, Exam Score: 73.7
# 14. S1311 - Attendance: 69.4, Exam Score: 67.0
# 15. S1332 - Attendance: 71.6, Exam Score: 71.2
# 16. S1340 - Attendance: 70.3, Exam Score: 80.3
# 17. S1350 - Attendance: 72.8, Exam Score: 54.0
# 18. S1365 - Attendance: 68.7, Exam Score: 70.8
# 19. S1370 - Attendance: 72.8, Exam Score: 73.7
# 20. S1380 - Attendance: 69.9, Exam Score: 67.7
# 21. S1412 - Attendance: 65.0, Exam Score: 73.7
# 22. S1435 - Attendance: 73.7, Exam Score: 58.3
# 23. S1436 - Attendance: 74.0, Exam Score: 78.4
# 24. S1451 - Attendance: 69.9, Exam Score: 58.6
# 25. S1458 - Attendance: 70.9, Exam Score: 59.0
# 26. S1462 - Attendance: 66.1, Exam Score: 80.9
# 27. S1470 - Attendance: 69.7, Exam Score: 60.4
# 28. S1476 - Attendance: 73.3, Exam Score: 74.8
# 29. S1481 - Attendance: 65.2, Exam Score: 84.6
# 30. S1493 - Attendance: 67.3, Exam Score: 73.9
#
# Note that this list might not be exhaustive, as there might be additional students who meet the criteria but are not included in the provided data.

# %% [markdown]
# **Pandas SQL**
# using the pandasql library, SQL query can be raised on data frame (treatig like a table)
# The psql library can handle basic SQL queries which are typically handled by SQLite
# Since it can be used as SQL queries, it can be integrated in RAG pipe line (query by LLM etc)

# %%
import pandasql as psql

# %%
Query = "SELECT * FROM Data WHERE extracurricular_participation = 'Yes'"

result = psql.sqldf(Query)

print(result)
